# %% [raw]
# ---
# title: "Подготовка воспроизводимых отчетов"
# format: md
# ---

# %% [markdown]
# ## Цель
#
# 1.  Развить практические навыки использования современного стека воспроизводимых исследований
# 2.  Закрепить знания о современных сетевых протоколах прикладного уровня
#
# ## ️Исходные данные
#
# 1.  Ноутбук c Windows 11 и установленным Git
# 2.  Дистрибутивы ПО: R-4.4.1-win.exe (интерпретатор R), RStudio-2024.04.2-764.exe (IDE)
#
# ## ️Общий план выполнения
#
# 1.  Скачать и установить дистрибутивы интерпретатора языка программирования R и среды разработки RStudio
# 2.  Создать проект и локальный репозиторий
# 3.  Создать отчет по практической работе
# 4.  Создать удаленный репозиторий на GitHub и связать его с локальным
# 5.  Добавить результат выполнения шагов отчет и получить рендер файла qmd в md
# 6.  Выполнить add, commit и push локального репозитория на Github
#
# ## Содержание ЛР
#
# ### Шаг 1
#
# Установлены R 4.4.1 и RStudio. ![](img/1.png)
#
# ### Шаг 2
#
# Создан проект и локальный репозиторий. ![](img/2.png)
#
# ### Шаг 3
#
# Создан отчет по практической работе в виде файла qmd ![](img/3.png)
#
# ### Шаг 4
#
# Создан удаленный репозиторий на GitHub ![](img/4.png) Связываем локальный репозиторий с удаленным
#
#
# ```{bash}
# #| git remote add reports_i2z1 https://github.com/MariUt005/reports_i2z1
# 2 * 2
# ```
